# %% [markdown]
# # Global Terrorism Attacks - Predicting The Responsible Group

# %% [markdown]
# **Table of Contents**
# <div id="toc"></div>

# %% [markdown]
# ## Load data

# %%
# %matplotlib inline

import pandas as pd
import csv
from tqdm import tqdm_notebook
from sklearn import preprocessing

gtd = pd.read_csv('gtd_converted.csv', encoding='latin1', low_memory=False)
gtd.columns
gtd.tail(5)
# Out:
#         Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 170345      170345  201612310040   2016      12    31        NaN         0
# 170346      170346  201612310042   2016      12    31        NaN         0
# 170347      170347  201612310043   2016      12    31        NaN         1
# 170348      170348  201612310044   2016      12    31        NaN         0
# 170349      170349  201701270001   2016      12    30        NaN         0
#
#        resolution  country                       country_txt   ...    \
# 170345        NaN      146                             Niger   ...
# 170346        NaN      160                       Philippines   ...
# 170347        NaN      229  Democratic Republic of the Congo   ...
# 170348        NaN      130                            Mexico   ...
# 170349        NaN      195                             Sudan   ...
#
#                                                  addnotes  \
# ...

# %%
# # Mapping for _txt columns
# txt_maps = {col[:-4]:{} for col in gtd.columns if col[-4:]=='_txt'}
# for index, row in tqdm_notebook(gtd.iterrows(), desc='Rows'):
#     for key in txt_maps:
#         if pd.notnull(row[key]):
#             txt_maps[key][int(row[key])] = row[key+'_txt']
#TODO: Fix progress bar - tqdm
#  # Save maps to CSV
# with open('mapping.csv', 'w') as csvfile:
#     writer = csv.writer(csvfile)
#     writer.writerows(txt_maps.items())

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Filter Columns

# %%
# keep_cols = ['gname', 'iyear', 'imonth', 'iday', 'country', 'provstate', 'city', 'region', 'crit1', 'crit2', 'crit3', 'doubtterr', 'success', 'attacktype1', 'targtype1', 'targsubtype1', 'natlty1', 'weaptype1', 'weapsubtype1', 'nperps', 'nkill', 'nwound', 'ransom']
keep_cols = ['gname', 'iyear', 'country', 'crit1', 'crit2', 'crit3', 'attacktype1', 'targtype1', 'targsubtype1', 'weaptype1', 'weapsubtype1', 'ransom']
# keep_cols = ['gname', 'iyear', 'country', 'attacktype1', 'weaptype1']

gtd = gtd[keep_cols]
gtd.tail(5)
# Out:
#                                gname  iyear  country  crit1  crit2  crit3  \
# 170345                    Boko Haram   2016      146      1      1      0
# 170346                       Unknown   2016      160      1      1      1
# 170347  Lord's Resistance Army (LRA)   2016      229      1      1      1
# 170348                       Unknown   2016      130      0      1      1
# 170349     Sudan Liberation Movement   2016      195      1      1      1
#
#         attacktype1  targtype1  targsubtype1  weaptype1  weapsubtype1  ransom
# 170345            9          4          34.0         13           NaN     NaN
# 170346            3         12           NaN          6          16.0     NaN
# 170347            6         14          75.0         13           NaN     0.0
# 170348            1         10          53.0          5           3.0     NaN
# 170349            2         14          75.0          5           5.0     NaN

# %% [markdown]
# ### Filter Groups

# %%
from collections import Counter

group_count = Counter(gtd['gname'])
# Remove groups with 3 attacks or less
filtered_groups = [group for group, counter in group_count.items() if counter > 3]
# Remove 'Unknown'
filtered_groups.remove('Unknown')

gtd = gtd[gtd['gname'].isin(filtered_groups)]

#TODO: Change floats to bools

# %%
### Transform Target

# %%
number = preprocessing.LabelEncoder()
gtd['gname'] = number.fit_transform(gtd.gname) #number.inverse_transform()
gtd = gtd.rename(columns={'gname': 'groupId'})

# %% [markdown]
# ### Fill NaNs

# %%
gtd=gtd.fillna(0) #TODO: 999 or 0?

gtd.tail(5)
# Out:
#         groupId  iyear  country  crit1  crit2  crit3  attacktype1  targtype1  \
# 170342      939   2016        4      1      1      0            9          4
# 170343      939   2016        4      1      1      1            3         17
# 170345      214   2016      146      1      1      0            9          4
# 170347      555   2016      229      1      1      1            6         14
# 170349      919   2016      195      1      1      1            2         14
#
#         targsubtype1  weaptype1  weapsubtype1  ransom
# 170342          27.0         13           0.0     0.0
# 170343          94.0          6          16.0     0.0
# 170345          34.0         13           0.0     0.0
# 170347          75.0         13           0.0     0.0
# 170349          75.0          5           5.0     0.0

# %%
gtd.to_csv('gtd_processed_11features.csv', encoding='utf-8', index=False)
